# %% [markdown]
# <font color=GREEN size=4><b>[𝐖𝐎𝐎𝐃𝐜𝐫𝐚𝐟𝐭](https://t.me/Farooq_is_KING)</b></font>
# <!-- RAINBOW LINE TOP -->
# <center><img src="https://github.com/SudoR2spr/SudoR2spr/raw/main/assets/line-neon.gif" width="100%">
#
# <!-- GIF HEADER -->
# <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/rclone.png" alt="Rclone Logo" height="100"></center>
# <img src="https://github.com/SudoR2spr/SudoR2spr/raw/main/assets/line-neon.gif" width="100%">
#
#
# [![Typing SVG](https://readme-typing-svg.herokuapp.com?font=Fira+Code&pause=1000&color=4250F7&background=FF512800&center=true&vCenter=true&width=435&lines=%F0%9D%90%96%F0%9D%90%8E%F0%9D%90%8E%F0%9D%90%83%F0%9D%90%9C%F0%9D%90%AB%F0%9D%90%9A%F0%9D%90%9F%F0%9D%90%AD+%F0%9D%90%8C%F0%9D%90%A2%F0%9D%90%AB%F0%9D%90%AB%F0%9D%90%A8%F0%9D%90%AB+%F0%9D%90%99%F0%9D%90%A8%F0%9D%90%A7%F0%9D%90%9E%E2%84%A2)](https://git.io/typing-svg)</p></center>

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/Angel-ji.png" alt="WD Logo" height="150"></center>
# <center><b>WOODcraft</b> By Rclone Transfer</center>

# %% [markdown]
# ####<font color=Orange size=4><b>🔧 Google Drive</b></font>

# %%
# @markdown <font color=GREEN size=4><b>🔗 Mount Google Drive</b></font>
# @markdown <p>📂 Run this if you want to transfer your files to your google drive Gdrive.</p>
# @markdown <center><img src="https://raw.githubusercontent.com/SudoR2spr/GoFile-Downloader/main/Op%20Source/logo/gdrive.png" alt="Drive logo" height="50"></center>

import os
delete_path = '/content/sample_data'
if os.path.exists(delete_path):
    # !rm -rf '/content/sample_data'

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ####<font color=GREEN size=4><b>🔗 Gdrive Downloader</b></font>

# %%
# @markdown <font color=GREEN size=4><b>🔧 Gdrive Downloader</b></font>
# @markdown <p>⬤ Change ***mode*** to \"file\" for link from single file link and \"folder\" for link from folder link. Fill ***id_link*** with only the id from url, not full url.</p>
# @markdown <center><img src="https://raw.githubusercontent.com/SudoR2spr/GoFile-Downloader/main/Op%20Source/logo/gdrive.png" alt="GDrive logo" height="50"></center>
import os
# @markdown <font color=GREEN size=4><b>🔧 Gdrive MODE</b></font>
mode = "file" # @param ["file", "folder"]
id_link = "" # @param {type:"string"}
output_path = "/content/drive/My Drive/Rclone" # @param {type:"string"}

import os
delete_path = '/content/sample_data'
if os.path.exists(delete_path):
    # !rm -rf '/content/sample_data'

try:
    os.makedirs(output_path, exist_ok=True)
except OSError as error:
    pass
os.chdir(output_path)

if mode == "file":
    command = f"gdown --remaining-ok {id_link}"
else:
    command = f"gdown --folder --remaining-ok {id_link}"

# !{command}

os.chdir('/content')

# %% [markdown]
# ####<font color=blue size=4><b>📁 Rclone Transfer</b></font>

# %%
# @markdown <font color=Green size=4><b>📁 Transfer Files with Rclone</b></font>
# @markdown <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/rclone.png" alt="gofile logo" height="50"></center>
# @markdown <p>⬤ Use <b>rclone_version</b> stable for official rclone, and <b>rclone_version</b> mod with additional support for teldrive. Fill <b>source</b> with source path or direct download link, <b>dest</b> with your destination path.</p>
rclone_version = "stable" # @param ["stable", "mod"]
source = "" # @param {type:"string"}
dest = "" # @param {type:"string"}

import os, urllib.request

if not os.path.exists("/content/peeklab.cpython-310-x86_64-linux-gnu.so"):
    urllib.request.urlretrieve("https://github.com/SudoR2spr/GoFile-Downloader/raw/main/Op%20Source/peeklab.cpython-310-x86_64-linux-gnu.so", "/content/peeklab.cpython-310-x86_64-linux-gnu.so")

from peeklab import installRclone, installRcloneM, uploadConf
from IPython.display import clear_output

if rclone_version == "stable":
    installRclone()
else:
    installRcloneM()

uploadConf()

if source.startswith("https://"):
    command = f"rclone copyurl -v --stats 1 --stats-one-line --checkers 16 --onedrive-encoding \"Slash\" -a --header-filename \"{source}\" \"{dest}\""
else:
    command = f"rclone copy -v --stats 1 --stats-one-line --checkers 16 --onedrive-encoding \"Slash\" --create-empty-src-dirs \"{source}\" \"{dest}\""

# !{command}
